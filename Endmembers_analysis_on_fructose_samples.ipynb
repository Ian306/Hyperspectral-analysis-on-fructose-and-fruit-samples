# %% [markdown]
# # Endmembers analysis on fructose samples

# %% [markdown]
# ## Read & format

# %%
pip install spectral
# Out:
# ...
#      |████████████████████████████████| 212 kB 9.9 MB/s
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt
from spectral import *

# %% [markdown]
# ### Sugar sample

# %%
hsi_sugar = open_image('/content/drive/MyDrive/verano multiespectral/azucar 2 /azucar__2022-01-28_19-22-15/capture/azucar__2022-01-28_19-22-15.hdr')
hsi_wet_sugar = open_image('/content/drive/MyDrive/verano multiespectral/azucar 2 /azucar__2022-01-28_19-26-00/capture/azucar__2022-01-28_19-26-00.hdr')
# Out:
# /usr/local/lib/python3.7/dist-packages/spectral/io/envi.py:175: UserWarning: Parameters with non-lowercase names encountered and converted to lowercase. To retain source file parameter name capitalization, set spectral.settings.envi_support_nonlowercase_params to True.
#   warnings.warn(msg)

# %%
hsi_sugar.bands.centers[0], hsi_sugar.bands.centers[-1]
# Out:
# (397.01, 1004.52)

# %%
hsi_wet_sugar.bands.centers[0], hsi_wet_sugar.bands.centers[-1]
# Out:
# (397.01, 1004.52)

# %%
hsi_sugar.shape, hsi_wet_sugar.shape
# Out:
# ((3397, 1024, 448), (3335, 1024, 448))

# %%
sample_band = 180
sample_band_img = hsi_sugar[:,:,sample_band]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(sample_band_img),cmap='jet')
plt.title('Image of band ' + str(hsi_sugar.bands.centers[sample_band]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sample_band = 180
sample_band_img = hsi_wet_sugar[:,:,sample_band]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(sample_band_img),cmap='jet')
plt.title('Image of band ' + str(hsi_wet_sugar.bands.centers[sample_band]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# 0% sample cutted 
hsi_0_sugar = hsi_sugar[150:1000,180:260,:]
hsi_0_sugar_sample = hsi_0_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_0_sugar_sample),cmap='jet')
plt.title('Image of 0% sample at band ' + str(hsi_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_0_sugar.shape
# Out:
# (850, 80, 448)

# %%
# 5% sample cutted 
hsi_5_sugar = hsi_sugar[130:1100,390:480,:]
hsi_5_sugar_sample = hsi_5_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_5_sugar_sample),cmap='jet')
plt.title('Image of 5% sample at band ' + str(hsi_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_5_sugar.shape
# Out:
# (970, 90, 448)

# %%
# 10% sample cutted 
hsi_10_sugar = hsi_sugar[160:1040,700:780,:]
hsi_10_sugar_sample = hsi_10_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_10_sugar_sample),cmap='jet')
plt.title('Image of 10% sample at band ' + str(hsi_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_10_sugar.shape
# Out:
# (880, 80, 448)

# %%
# 15% sample cutted 
hsi_15_sugar = hsi_sugar[1800:2600,200:270,:]
hsi_15_sugar_sample = hsi_15_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_15_sugar_sample),cmap='jet')
plt.title('Image of 15% sample at band ' + str(hsi_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_15_sugar.shape
# Out:
# (800, 70, 448)

# %%
# 20% sample cutted 
hsi_20_sugar = hsi_sugar[1600:2710,410:480,:]
hsi_20_sugar_sample = hsi_20_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_20_sugar_sample),cmap='jet')
plt.title('Image of 20% sample at band ' + str(hsi_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_20_sugar.shape
# Out:
# (1110, 70, 448)

# %%
# 25% sample cutted 
hsi_25_sugar = hsi_sugar[1480:2600,700:780,:]
hsi_25_sugar_sample = hsi_25_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_25_sugar_sample),cmap='jet')
plt.title('Image of 25% sample at band ' + str(hsi_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_25_sugar.shape
# Out:
# (1120, 80, 448)

# %%
# 5% wet sample cutted 
hsi_5_wet_sugar = hsi_wet_sugar[40:980,450:560,:]
hsi_5_wet_sugar_sample = hsi_5_wet_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_5_wet_sugar_sample),cmap='jet')
plt.title('Image of 5% wet sample at band ' + str(hsi_wet_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_5_wet_sugar.shape
# Out:
# (940, 110, 448)

# %%
# 10% wet sample cutted 
hsi_10_wet_sugar = hsi_wet_sugar[40:760,750:830,:]
hsi_10_wet_sugar_sample = hsi_10_wet_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_10_wet_sugar_sample),cmap='jet')
plt.title('Image of 10% wet sample at band ' + str(hsi_wet_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_10_wet_sugar.shape
# Out:
# (720, 80, 448)

# %%
# 15% wet sample cutted 
hsi_15_wet_sugar = hsi_wet_sugar[1700:2500,200:290,:]
hsi_15_wet_sugar_sample = hsi_15_wet_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_15_wet_sugar_sample),cmap='jet')
plt.title('Image of 15% wet sample at band ' + str(hsi_wet_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_15_wet_sugar.shape

# %%
# 20% wet sample cutted 
hsi_20_wet_sugar = hsi_wet_sugar[1800:2700,430:520,:]
hsi_20_wet_sugar_sample = hsi_20_wet_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_20_wet_sugar_sample),cmap='jet')
plt.title('Image of 20% wet sample at band ' + str(hsi_wet_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_20_wet_sugar.shape

# %%
# 25% wet sample cutted 
hsi_25_wet_sugar = hsi_wet_sugar[1700:2450,720:820,:]
hsi_25_wet_sugar_sample = hsi_25_wet_sugar[:,:,180]
plt.figure(1)
plt.clf()
plt.imshow(np.squeeze(hsi_25_wet_sugar_sample),cmap='jet')
plt.title('Image of 25% wet sample at band ' + str(hsi_wet_sugar.bands.centers[180]) + ' nm '  )
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
hsi_25_wet_sugar.shape
# Out:
# (750, 100, 448)

# %% [markdown]
# ## Endmembers extraction

# %%
pip install pysptools
# Out:
# ...
#      |████████████████████████████████| 8.1 MB 14.9 MB/s
# ...
#   Created wheel for pysptools: filename=pysptools-0.15.0-py3-none-any.whl size=8133751 sha256=0ae6d524a7efabf9f3a7dbc56ea6d77813e01bf3ba907e40daa1a8d7e0731bb3
#   Stored in directory: /root/.cache/pip/wheels/ee/61/31/fb8bf9e1d7508efcfce674a9dc4ac98e67cfe875a5567c4e7e
# Successfully built pysptools
# ...

# %%
import pysptools.util as util
import pysptools.eea as eea #endmembers extraction algorithms
import pysptools.abundance_maps as amap
import pysptools.classification as cls
import pysptools.material_count as cnt

# %%
def get_endmembers(hsi_cutted, hsi_original, num_end_members, pc=0): 
    end_mmbrs_findr = eea.NFINDR()
    end_mmbrs = end_mmbrs_findr.extract(hsi_cutted, num_end_members, maxit=5, normalize=False,ATGP_init=True)

    if (pc == 0):      
        wavelengths = hsi_original.bands.centers
    else: 
        wavelengths = pc

    ee_axes = {} # set ee_axes data type to dictionary
    # cast wavelength values to float to apply to ee_axes for display purposes 
    ee_axes['wavelength'] = wavelengths
    ee_axes['x']='Wavelength, nm' #x axis label 
    ee_axes['y']='Reflectance' #y axis label 

    end_mmbrs_findr.display(axes=ee_axes)
    return end_mmbrs

# %%
end_mmbrs_0_sugar = get_endmembers(hsi_0_sugar, hsi_sugar, 2)

# %%
end_mmbrs_5_sugar = get_endmembers(hsi_5_sugar, hsi_sugar, 2)

# %%
end_mmbrs_10_sugar = get_endmembers(hsi_10_sugar, hsi_sugar, 2)

# %%
end_mmbrs_15_sugar = get_endmembers(hsi_15_sugar, hsi_sugar, 2)

# %%
end_mmbrs_20_sugar = get_endmembers(hsi_20_sugar, hsi_sugar, 2)

# %%
end_mmbrs_25_sugar = get_endmembers(hsi_25_sugar, hsi_sugar, 2)

# %%
end_mmbrs_5_wet_sugar = get_endmembers(hsi_5_wet_sugar, hsi_wet_sugar, 2)

# %%
end_mmbrs_10_wet_sugar = get_endmembers(hsi_10_wet_sugar, hsi_wet_sugar, 2)

# %%
end_mmbrs_15_wet_sugar = get_endmembers(hsi_15_wet_sugar, hsi_wet_sugar, 2)

# %%
end_mmbrs_20_wet_sugar = get_endmembers(hsi_20_wet_sugar, hsi_wet_sugar, 2)

# %%
end_mmbrs_25_wet_sugar = get_endmembers(hsi_25_wet_sugar, hsi_wet_sugar, 2)
